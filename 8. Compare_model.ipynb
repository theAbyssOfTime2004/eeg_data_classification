# %% [markdown]
# # So sánh model.

# %% [markdown]
# #1.So sánh Performance.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Dựa trên các chỉ số hiệu suất được cung cấp, có thể thấy rằng các mô hình KNN và SVM đang thể hiện những kết quả tốt nhất. Đây là những mô hình cân bằng và toàn diện, với độ chính xác và độ nhạy đáng kể.
# Cụ thể hơn, các mô hình KNN và SVM có độ chính xác dự đoán (precision) ấn tượng, đạt tới 88%. Điều này cho thấy chúng có khả năng hạn chế các dự đoán dương tính giả một cách hiệu quả. Về độ nhạy (recall), KNN và SVM cũng thể hiện mức độ tương đối tốt, gần 80%.
# Khi cân bằng cả độ chính xác và độ nhạy, các mô hình này đạt được điểm F1 cao nhất, ở mức 0,81-0,84. Chỉ số này phản ánh sự cân bằng tối ưu giữa hai tiêu chí này. Điều này đồng thời được khẳng định thông qua độ chính xác trên tập kiểm tra, lên tới 88% - mức cao nhất trong số các mô hình so sánh.
# Mô hình XGBoost cũng thể hiện hiệu suất ấn tượng, đặc biệt về độ nhạy ở mức 84%. Tuy nhiên, độ chính xác của nó hơi thấp hơn so với KNN và SVM. Điểm F1 và độ chính xác trên tập kiểm tra cũng đạt mức tốt, nhưng chưa bằng hai mô hình hàng đầu.
# Mô hình CNN lại tỏ ra kém hơn so với các đối thủ khác trên hầu hết các chỉ số. Độ chính xác thấp, chỉ 55%, cho thấy nó có khả năng cao trong việc dự đoán sai lệch. Các chỉ số khác như độ nhạy, điểm F1 và độ chính xác trên tập kiểm tra cũng đều thấp nhất trong số các mô hình.
# Nhìn chung, KNN và SVM thực sự nổi bật với hiệu suất toàn diện và cân bằng. XGBoost cũng là một mô hình đáng chú ý, đặc biệt về độ nhạy. Trong khi đó, CNN dường như cần được cải thiện nhiều hơn để có thể cạnh tranh với các mô hình hàng đầu khác.

# %% [markdown]
# #2. So Sánh Hiệu Suất train.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Khi train model bằng GPU sử dụng pytorch thì XGboost KNN SVM train khá ổn, nhưng dối với CNN xữ lí hình ảnh thì thơi gian train vượt trội và kết quả cũng không ra chính xác.
